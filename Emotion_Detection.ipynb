# %%
# Set seeds for reproducibility
import random
random.seed(0)

import numpy as np
np.random.seed(0)

import tensorflow as tf
tf.random.set_seed(0)

# %%
import os
import json
from zipfile import ZipFile
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.7.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
! kaggle datasets download -d jonathanoheix/face-expression-recognition-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jonathanoheix/face-expression-recognition-dataset
# License(s): unknown
# face-expression-recognition-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# Emotiondetector.json   face-expression-recognition-dataset.zip	sample_data
# Emotiondetector.keras  images

# %%
# Unzip the downloaded dataset
with ZipFile("face-expression-recognition-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
# !pip install keras-preprocessing
# Out:
# Requirement already satisfied: keras-preprocessing in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-preprocessing) (1.26.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras-preprocessing) (1.16.0)

# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/validation'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
print(train)
# Out:
# happy completed
# surprise completed
# angry completed
# fear completed
# sad completed
# disgust completed
# neutral completed
#                                 image    label
# 0         images/train/happy/5779.jpg    happy
# 1        images/train/happy/23249.jpg    happy
# 2         images/train/happy/2136.jpg    happy
# 3        images/train/happy/14905.jpg    happy
# 4         images/train/happy/5433.jpg    happy
# ...                               ...      ...
# 28816   images/train/neutral/5648.jpg  neutral
# 28817  images/train/neutral/22801.jpg  neutral
# 28818  images/train/neutral/30385.jpg  neutral
# 28819  images/train/neutral/31688.jpg  neutral
# 28820  images/train/neutral/12023.jpg  neutral
#
# [28821 rows x 2 columns]

# %%
validation = pd.DataFrame()
validation['image'], validation['label'] = createdataframe(TEST_DIR)
print(validation)
# Out:
# happy completed
# surprise completed
# angry completed
# fear completed
# sad completed
# disgust completed
# neutral completed
#                                     image    label
# 0       images/validation/happy/23667.jpg    happy
# 1       images/validation/happy/33071.jpg    happy
# 2       images/validation/happy/24055.jpg    happy
# 3        images/validation/happy/5264.jpg    happy
# 4         images/validation/happy/531.jpg    happy
# ...                                   ...      ...
# 7061  images/validation/neutral/14980.jpg  neutral
# 7062   images/validation/neutral/1819.jpg  neutral
# 7063  images/validation/neutral/18973.jpg  neutral
# 7064  images/validation/neutral/15651.jpg  neutral
# 7065  images/validation/neutral/15721.jpg  neutral
#
# [7066 rows x 2 columns]

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, grayscale=True)
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
from tqdm.notebook import tqdm

# %%
train_features = extract_features(train['image'])
test_features = extract_features(validation['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features / 255.0
x_test = test_features / 255.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(train['label'])
y_train = le.transform(train['label'])
y_test = le.transform(validation['label'])
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Initialize the Sequential model
model = Sequential()

# Add convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# Flatten the output from the convolutional layers
model.add(Flatten())

# Add fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

# Add the output layer
model.add(Dense(7, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])  # Metrics should be a list

# Print the model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 128)         │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 23, 23, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10, 10, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1, 1, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           1,799 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,232,199 (16.14 MB)
#  Trainable params: 4,232,199 (16.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x= x_train, y=y_train, batch_size=120, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 39s 119ms/step - accuracy: 0.2312 - loss: 1.8375 - val_accuracy: 0.2583 - val_loss: 1.8009
# Epoch 2/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 15s 45ms/step - accuracy: 0.2491 - loss: 1.7932 - val_accuracy: 0.3197 - val_loss: 1.6693
# Epoch 3/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.3249 - loss: 1.6720 - val_accuracy: 0.3985 - val_loss: 1.5319
# Epoch 4/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.3924 - loss: 1.5559 - val_accuracy: 0.4676 - val_loss: 1.3863
# Epoch 5/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.4298 - loss: 1.4712 - val_accuracy: 0.5038 - val_loss: 1.3050
# Epoch 6/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4595 - loss: 1.4094 - val_accuracy: 0.5208 - val_loss: 1.2675
# Epoch 7/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4743 - loss: 1.3673 - val_accuracy: 0.5183 - val_loss: 1.2623
# Epoch 8/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.4896 - loss: 1.3492 - val_accuracy: 0.5364 - val_loss: 1.2163
# Epoch 9/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4931 - loss: 1.3205 - val_accuracy: 0.5463 - val_loss: 1.1911
# Epoch 10/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5051 - loss: 1.3001 - val_accuracy: 0.5466 - val_loss: 1.1869
# Epoch 11/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5089 - loss: 1.2794 - val_accuracy: 0.5579 - val_loss: 1.1596
# Epoch 12/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5193 - loss: 1.2575 - val_accuracy: 0.5603 - val_loss: 1.1539
# Epoch 13/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5205 - loss: 1.2409 - val_accuracy: 0.5712 - val_loss: 1.1376
# Epoch 14/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5314 - loss: 1.2304 - val_accuracy: 0.5698 - val_loss: 1.1263
# Epoch 15/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5362 - loss: 1.2175 - val_accuracy: 0.5754 - val_loss: 1.1316
# Epoch 16/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5422 - loss: 1.2021 - val_accuracy: 0.5760 - val_loss: 1.1253
# Epoch 17/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5524 - loss: 1.1813 - val_accuracy: 0.5793 - val_loss: 1.1062
# Epoch 18/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5512 - loss: 1.1873 - val_accuracy: 0.5845 - val_loss: 1.1136
# Epoch 19/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5541 - loss: 1.1760 - val_accuracy: 0.5810 - val_loss: 1.1085
# Epoch 20/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5550 - loss: 1.1711 - val_accuracy: 0.5916 - val_loss: 1.0961
# Epoch 21/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.5595 - loss: 1.1514 - val_accuracy: 0.5911 - val_loss: 1.1006
# Epoch 22/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5645 - loss: 1.1434 - val_accuracy: 0.5904 - val_loss: 1.1054
# Epoch 23/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5655 - loss: 1.1375 - val_accuracy: 0.5967 - val_loss: 1.0776
# Epoch 24/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5775 - loss: 1.1179 - val_accuracy: 0.5918 - val_loss: 1.0864
# Epoch 25/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5722 - loss: 1.1210 - val_accuracy: 0.5911 - val_loss: 1.0936
# Epoch 26/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5771 - loss: 1.1211 - val_accuracy: 0.5954 - val_loss: 1.0833
# Epoch 27/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - accuracy: 0.5803 - loss: 1.1072 - val_accuracy: 0.5958 - val_loss: 1.0820
# Epoch 28/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5880 - loss: 1.0886 - val_accuracy: 0.5914 - val_loss: 1.0751
# Epoch 29/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5945 - loss: 1.0821 - val_accuracy: 0.5978 - val_loss: 1.0707
# Epoch 30/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5888 - loss: 1.0915 - val_accuracy: 0.6027 - val_loss: 1.0659
# Epoch 31/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.5956 - loss: 1.0762 - val_accuracy: 0.6085 - val_loss: 1.0633
# Epoch 32/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5977 - loss: 1.0607 - val_accuracy: 0.6063 - val_loss: 1.0738
# Epoch 33/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5978 - loss: 1.0683 - val_accuracy: 0.6068 - val_loss: 1.0687
# Epoch 34/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6022 - loss: 1.0506 - val_accuracy: 0.6030 - val_loss: 1.0633
# Epoch 35/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5985 - loss: 1.0644 - val_accuracy: 0.6108 - val_loss: 1.0508
# Epoch 36/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6062 - loss: 1.0426 - val_accuracy: 0.6094 - val_loss: 1.0487
# Epoch 37/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6082 - loss: 1.0387 - val_accuracy: 0.6095 - val_loss: 1.0507
# Epoch 38/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6086 - loss: 1.0388 - val_accuracy: 0.6100 - val_loss: 1.0476
# Epoch 39/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6119 - loss: 1.0334 - val_accuracy: 0.6059 - val_loss: 1.0633
# Epoch 40/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6103 - loss: 1.0165 - val_accuracy: 0.6122 - val_loss: 1.0470
# Epoch 41/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6111 - loss: 1.0228 - val_accuracy: 0.6127 - val_loss: 1.0553
# Epoch 42/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6217 - loss: 1.0077 - val_accuracy: 0.6076 - val_loss: 1.0443
# Epoch 43/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6293 - loss: 0.9879 - val_accuracy: 0.6207 - val_loss: 1.0321
# Epoch 44/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6225 - loss: 0.9973 - val_accuracy: 0.6173 - val_loss: 1.0408
# Epoch 45/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6211 - loss: 0.9943 - val_accuracy: 0.6151 - val_loss: 1.0430
# Epoch 46/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6291 - loss: 0.9874 - val_accuracy: 0.6217 - val_loss: 1.0401
# Epoch 47/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6300 - loss: 0.9733 - val_accuracy: 0.6196 - val_loss: 1.0380
# Epoch 48/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6381 - loss: 0.9734 - val_accuracy: 0.6168 - val_loss: 1.0418
# Epoch 49/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6378 - loss: 0.9600 - val_accuracy: 0.6163 - val_loss: 1.0379
# Epoch 50/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6395 - loss: 0.9516 - val_accuracy: 0.6182 - val_loss: 1.0434
# Epoch 51/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6337 - loss: 0.9734 - val_accuracy: 0.6202 - val_loss: 1.0339
# Epoch 52/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6379 - loss: 0.9567 - val_accuracy: 0.6148 - val_loss: 1.0445
# Epoch 53/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6425 - loss: 0.9466 - val_accuracy: 0.6196 - val_loss: 1.0444
# Epoch 54/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6472 - loss: 0.9437 - val_accuracy: 0.6219 - val_loss: 1.0328
# Epoch 55/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6459 - loss: 0.9379 - val_accuracy: 0.6240 - val_loss: 1.0368
# Epoch 56/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6495 - loss: 0.9424 - val_accuracy: 0.6206 - val_loss: 1.0459
# Epoch 57/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6542 - loss: 0.9264 - val_accuracy: 0.6203 - val_loss: 1.0435
# Epoch 58/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6516 - loss: 0.9240 - val_accuracy: 0.6214 - val_loss: 1.0367
# Epoch 59/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6492 - loss: 0.9266 - val_accuracy: 0.6233 - val_loss: 1.0299
# Epoch 60/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6536 - loss: 0.9176 - val_accuracy: 0.6216 - val_loss: 1.0373
# Epoch 61/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6571 - loss: 0.9234 - val_accuracy: 0.6281 - val_loss: 1.0248
# Epoch 62/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6608 - loss: 0.8995 - val_accuracy: 0.6223 - val_loss: 1.0414
# Epoch 63/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6616 - loss: 0.9022 - val_accuracy: 0.6231 - val_loss: 1.0417
# Epoch 64/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6680 - loss: 0.8973 - val_accuracy: 0.6202 - val_loss: 1.0435
# Epoch 65/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.6664 - loss: 0.9042 - val_accuracy: 0.6250 - val_loss: 1.0410
# Epoch 66/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6713 - loss: 0.8880 - val_accuracy: 0.6243 - val_loss: 1.0481
# Epoch 67/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6688 - loss: 0.8963 - val_accuracy: 0.6235 - val_loss: 1.0447
# Epoch 68/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6720 - loss: 0.8895 - val_accuracy: 0.6250 - val_loss: 1.0376
# Epoch 69/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6738 - loss: 0.8781 - val_accuracy: 0.6261 - val_loss: 1.0405
# Epoch 70/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.6778 - loss: 0.8626 - val_accuracy: 0.6298 - val_loss: 1.0244
# Epoch 71/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6778 - loss: 0.8661 - val_accuracy: 0.6319 - val_loss: 1.0272
# Epoch 72/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6792 - loss: 0.8549 - val_accuracy: 0.6251 - val_loss: 1.0441
# Epoch 73/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6842 - loss: 0.8507 - val_accuracy: 0.6306 - val_loss: 1.0381
# Epoch 74/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6808 - loss: 0.8605 - val_accuracy: 0.6258 - val_loss: 1.0372
# Epoch 75/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6875 - loss: 0.8529 - val_accuracy: 0.6244 - val_loss: 1.0681
# Epoch 76/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6882 - loss: 0.8483 - val_accuracy: 0.6265 - val_loss: 1.0357
# Epoch 77/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6880 - loss: 0.8435 - val_accuracy: 0.6262 - val_loss: 1.0360
# Epoch 78/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6974 - loss: 0.8296 - val_accuracy: 0.6305 - val_loss: 1.0476
# Epoch 79/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6961 - loss: 0.8265 - val_accuracy: 0.6286 - val_loss: 1.0362
# Epoch 80/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6900 - loss: 0.8431 - val_accuracy: 0.6298 - val_loss: 1.0407
# Epoch 81/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.7000 - loss: 0.8123 - val_accuracy: 0.6342 - val_loss: 1.0369
# Epoch 82/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6953 - loss: 0.8355 - val_accuracy: 0.6337 - val_loss: 1.0372
# Epoch 83/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6952 - loss: 0.8227 - val_accuracy: 0.6245 - val_loss: 1.0546
# Epoch 84/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7019 - loss: 0.8166 - val_accuracy: 0.6291 - val_loss: 1.0341
# Epoch 85/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.6959 - loss: 0.8310 - val_accuracy: 0.6298 - val_loss: 1.0451
# Epoch 86/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.7025 - loss: 0.8016 - val_accuracy: 0.6323 - val_loss: 1.0337
# Epoch 87/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.7080 - loss: 0.8003 - val_accuracy: 0.6326 - val_loss: 1.0297
# Epoch 88/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.7061 - loss: 0.8024 - val_accuracy: 0.6272 - val_loss: 1.0503
# Epoch 89/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.7043 - loss: 0.8034 - val_accuracy: 0.6353 - val_loss: 1.0519
# Epoch 90/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.7101 - loss: 0.7848 - val_accuracy: 0.6288 - val_loss: 1.0359
# Epoch 91/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7079 - loss: 0.7941 - val_accuracy: 0.6340 - val_loss: 1.0293
# Epoch 92/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.7112 - loss: 0.7923 - val_accuracy: 0.6274 - val_loss: 1.0563
# Epoch 93/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.7113 - loss: 0.7849 - val_accuracy: 0.6333 - val_loss: 1.0334
# Epoch 94/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7132 - loss: 0.7774 - val_accuracy: 0.6302 - val_loss: 1.0541
# Epoch 95/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.7206 - loss: 0.7706 - val_accuracy: 0.6377 - val_loss: 1.0385
# Epoch 96/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.7168 - loss: 0.7749 - val_accuracy: 0.6418 - val_loss: 1.0330
# Epoch 97/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.7218 - loss: 0.7653 - val_accuracy: 0.6359 - val_loss: 1.0390
# Epoch 98/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.7160 - loss: 0.7726 - val_accuracy: 0.6346 - val_loss: 1.0420
# Epoch 99/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.7275 - loss: 0.7565 - val_accuracy: 0.6289 - val_loss: 1.0450
# Epoch 100/100
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.7213 - loss: 0.7687 - val_accuracy: 0.6301 - val_loss: 1.0435

# %% [markdown]
# **Loading the Model and Making Predictions**

# %%
model_json = model.to_json()
with open("emotiondetector.json", 'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.keras")

# %%
from keras.models import model_from_json
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.keras")

# %%
label = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
def ef(image):
    img = load_img(image, grayscale=True)
    feature = np.array(img)
    feature = feature.reshape(1, 48, 48, 1)
    return feature / 255.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/train/angry/22.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ", pred_label)
plt.imshow(img.reshape(48, 48), cmap='gray')
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# model prediction is  angry

# %%
image = 'images/train/angry/27.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ", pred_label)
plt.imshow(img.reshape(48, 48), cmap='gray')
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# model prediction is  angry

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ", pred_label)
plt.imshow(img.reshape(48, 48), cmap='gray')
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# model prediction is  sad

# %%
image = 'images/train/sad/3.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# model prediction is  sad

# %%
image = 'images/train/happy/7.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# model prediction is  happy

# %%
image = 'images/train/disgust/299.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# model prediction is  disgust
